# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# https://pypi.org/project/yfinance/
import yfinance as yf
import random

# %%
sns.set_style('whitegrid') # background
get_ipython().magic(u'matplotlib inline')

# %%
# Reading stock data from the internet using pandas
import pandas_datareader.data as web

# %%
# Time stamps
from datetime import datetime

# %%
# Float numbers
from __future__ import division

# %% [markdown]
# ## Fetch Data

# %%
stonks_df = pd.read_csv('stonks.csv')
stonks_df.head()
stonk_tickers = stonks_df['STOCK SYMBOL'].dropna().tolist()

# %%
# valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
# (optional, default is '1mo')

# valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
# (optional, default is '1d')

data = yf.download(" ".join(stonk_tickers), group_by='Ticker', period='5y', interval='1wk')

# reassign stonk tickers
stonk_tickers = data.columns.levels[0].tolist()
# Out:
# [*********************100%***********************]  40 of 40 completed
#
# 14 Failed downloads:
# - TSE:PSYK: No data found, symbol may be delisted
# - RBOT: No data found for this date range, symbol may be delisted
# - TSE:VFF: No data found, symbol may be delisted
# - TSE:SCR: No data found, symbol may be delisted
# - XIU: No data found for this date range, symbol may be delisted
# - CYBR.B: No data found, symbol may be delisted
# - TSE:WELL: No data found, symbol may be delisted
# - TSE:CARE: No data found, symbol may be delisted
# - TSE:FOOD: No data found, symbol may be delisted
# - TSE:AC: No data found, symbol may be delisted
# - TSE:XIN: No data found, symbol may be delisted
# - TSE:CNR: No data found, symbol may be delisted
# - TSE:XSP: No data found, symbol may be delisted
# - HBLK: No data found, symbol may be delisted
# ...

# %% [markdown]
# ## Preview Data

# %%
data.head()

# %% [markdown]
# ## Single Stonk Analysis

# %%
# Select a random stonk from tickers
stonk_ticker = random.choice(stonk_tickers)

stonk = yf.Ticker(stonk_ticker)
stonk.info

# single stock dataframe
ssdf = data[stonk_ticker]

# %% [markdown]
# ### Daily closing price

# %%
ssdf['Adj Close'].plot(legend=True, figsize=(10,4))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Total daily volume

# %%
ssdf['Volume'].plot(legend=True, figsize=(10,4))
plt.show()

# %%
# Calculate the moving average of the stock
ma_day = [10,20,50]

for ma in ma_day:
    column_name = "MA for %s days"%(str(ma))

    ssdf[column_name] = ssdf['Adj Close'].rolling(window=ma).mean()

# %% [markdown]
# ### Moving average of closing price

# %%
ssdf[['Close','MA for 10 days','MA for 20 days','MA for 50 days']].plot(subplots=False,figsize=(10,4))
plt.show()

# %% [markdown]
# ### Daily returns

# %%
# Analyse daily returns of stonk
ssdf['Daily Return'] = ssdf['Adj Close'].pct_change()
ssdf['Daily Return'].plot(figsize=(10, 4), legend=True, linestyle='--', marker='o')
plt.show()
# Out:
# /Users/aperkslabbe/opt/anaconda3/envs/stonk_analysis/lib/python3.8/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %% [markdown]
# ### Avg daily return of the last year

# %%
sns.displot(ssdf['Daily Return'].dropna(), bins=100, color='red')
plt.show()

# %%
ssdf['Daily Return'].hist(bins=100)
plt.show()

# %% [markdown]
# ## Stonk List Analysis

# %%
# Refetch data without regrouping

# valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
# (optional, default is '1mo')

# valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
# (optional, default is '1d')

data = yf.download(" ".join(stonk_tickers), period='5y', interval='1wk')
# Out:
# [*********************100%***********************]  40 of 40 completed
#
# 14 Failed downloads:
# - RBOT: No data found for this date range, symbol may be delisted
# - TSE:VFF: No data found, symbol may be delisted
# - TSE:PSYK: No data found, symbol may be delisted
# - TSE:SCR: No data found, symbol may be delisted
# - XIU: No data found for this date range, symbol may be delisted
# - TSE:CARE: No data found, symbol may be delisted
# - CYBR.B: No data found, symbol may be delisted
# - TSE:XIN: No data found, symbol may be delisted
# - TSE:WELL: No data found, symbol may be delisted
# - TSE:AC: No data found, symbol may be delisted
# - TSE:XSP: No data found, symbol may be delisted
# - TSE:FOOD: No data found, symbol may be delisted
# - TSE:CNR: No data found, symbol may be delisted
# - HBLK: No data found, symbol may be delisted

# %%
data.head()
# Out:
#                      Adj Close                                             \
#                           AAPL   AMD       ATVI    BB BUZZ BYND COUR CRWD
# Date
# 2016-07-18 00:00:00  23.041672  5.84  40.189838  6.88  NaN  NaN  NaN  NaN
# 2016-07-25 00:00:00  24.337851  6.86  38.948456  7.60  NaN  NaN  NaN  NaN
# 2016-07-26 00:00:00        NaN   NaN        NaN   NaN  NaN  NaN  NaN  NaN
# 2016-08-01 00:00:00  25.101549  6.61  39.336388  7.75  NaN  NaN  NaN  NaN
# 2016-08-04 00:00:00        NaN   NaN        NaN   NaN  NaN  NaN  NaN  NaN
#
#                                  ...  Volume                           \
#                     CYBR.B DDOG  ... TSE:VFF TSE:WELL TSE:XIN TSE:XSP
# Date                             ...
# 2016-07-18 00:00:00    NaN  NaN  ...     NaN      NaN     NaN     NaN
# 2016-07-25 00:00:00    NaN  NaN  ...     NaN      NaN     NaN     NaN
# 2016-07-26 00:00:00    NaN  NaN  ...     NaN      NaN     NaN     NaN
# ...

# %%
closing_df = data['Adj Close']
closing_df.head()
# Out:
#                           AAPL   AMD       ATVI    BB  BUZZ  BYND  COUR  CRWD  \
# Date
# 2016-07-18 00:00:00  23.041672  5.84  40.189838  6.88   NaN   NaN   NaN   NaN
# 2016-07-25 00:00:00  24.337851  6.86  38.948456  7.60   NaN   NaN   NaN   NaN
# 2016-07-26 00:00:00        NaN   NaN        NaN   NaN   NaN   NaN   NaN   NaN
# 2016-08-01 00:00:00  25.101549  6.61  39.336388  7.75   NaN   NaN   NaN   NaN
# 2016-08-04 00:00:00        NaN   NaN        NaN   NaN   NaN   NaN   NaN   NaN
#
#                      CYBR.B  DDOG  ...  TSE:VFF  TSE:WELL  TSE:XIN  TSE:XSP  \
# Date                               ...
# 2016-07-18 00:00:00     NaN   NaN  ...      NaN       NaN      NaN      NaN
# 2016-07-25 00:00:00     NaN   NaN  ...      NaN       NaN      NaN      NaN
# 2016-07-26 00:00:00     NaN   NaN  ...      NaN       NaN      NaN      NaN
# 2016-08-01 00:00:00     NaN   NaN  ...      NaN       NaN      NaN      NaN
# ...

# %% [markdown]
# ## Daily return

# %%
daily_returns = closing_df.pct_change()
daily_returns.head()
# Out:
#                          AAPL       AMD      ATVI        BB  BUZZ  BYND  COUR  \
# Date
# 2016-07-18 00:00:00       NaN       NaN       NaN       NaN   NaN   NaN   NaN
# 2016-07-25 00:00:00  0.056254  0.174658 -0.030888  0.104651   NaN   NaN   NaN
# 2016-07-26 00:00:00  0.000000  0.000000  0.000000  0.000000   NaN   NaN   NaN
# 2016-08-01 00:00:00  0.031379 -0.036443  0.009960  0.019737   NaN   NaN   NaN
# 2016-08-04 00:00:00  0.000000  0.000000  0.000000  0.000000   NaN   NaN   NaN
#
#                      CRWD  CYBR.B  DDOG  ...  TSE:VFF  TSE:WELL  TSE:XIN  \
# Date                                     ...
# 2016-07-18 00:00:00   NaN     NaN   NaN  ...      NaN       NaN      NaN
# 2016-07-25 00:00:00   NaN     NaN   NaN  ...      NaN       NaN      NaN
# 2016-07-26 00:00:00   NaN     NaN   NaN  ...      NaN       NaN      NaN
# 2016-08-01 00:00:00   NaN     NaN   NaN  ...      NaN       NaN      NaN
# 2016-08-04 00:00:00   NaN     NaN   NaN  ...      NaN       NaN      NaN
#
# ...

# %% [markdown]
# ## Compare daily return of 2 stonks

# %%
stonk1 = random.choice(stonk_tickers)
stonk2 = random.choice(stonk_tickers)
sns.jointplot(x=stonk1, y=stonk2, data=daily_returns, kind='scatter', color='purple')

# %% [markdown]
# ## Compare daily return of multiple stonks

# %%
from IPython.display import SVG
SVG(url='http://upload.wikimedia.org/wikipedia/commons/d/d4/Correlation_examples2.svg')

# %%
sns.pairplot(daily_returns)
plt.show()
plt.savefig('daily_returns')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-203-f00723351bc4> in <module>
# ----> 1 sns.pairplot(daily_returns)
#       2 plt.show()
#       3 plt.savefig('daily_returns')
#
# ~/opt/anaconda3/envs/stonk_analysis/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/envs/stonk_analysis/lib/python3.8/site-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    1987     # Set up the PairGrid
#    1988     grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# ...

# %% [markdown]
# ## Compare different stonks daily returns

# %%
daily_returns_fig = sns.PairGrid(daily_returns)
daily_returns_fig.map_upper(plt.scatter, color='blue')
daily_returns_fig.map_lower(sns.kdeplot, cmap='cool_d')
daily_returns_fig.map_diag(plt.hist, bins=30, color='grey')
plt.show()

# %% [markdown]
# ## Risk Analysis
#
# ### Analyse risk of a stock

# %%
area = np.pi*20
ret = daily_returns.dropna()

plt.figure(dpi=350)
plt.scatter(ret.mean(), ret.std(), s = area)
plt.xlabel('Expected Return')
plt.ylabel('Risk')

for label, x, y in zip(ret.columns, ret.mean(), ret.std()):
    plt.annotate(
        label,
        xy = (x, y),
        xytext = (5, 5),
        textcoords = 'offset points', 
        ha = 'right', 
        va = 'bottom', 
        arrowprops = dict(
            arrowstyle = '-', 
            connectionstyle = 'arc3, rad=-0.3'
        )
    )
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# ~/opt/anaconda3/envs/stonk_analysis/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/opt/anaconda3/envs/stonk_analysis/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ...

# %% [markdown]
# ### Value at Risk

# %%
sns.distplot(sdf['Daily Return'].dropna(), bins=100, color='purple')
print(stonk)
plt.show()
# Out:
# /Users/aperkslabbe/opt/anaconda3/envs/stonk_analysis/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# NKE

# %%
ret.head()
# Out:
#                 AAPL      ATVI      COUR      CRWD      DELL      MSFT  \
# Date
# 2021-04-01  0.006959  0.027312  0.017333  0.024766  0.010550  0.027909
# 2021-04-05  0.023577  0.024388  0.083661 -0.002192  0.003143  0.027728
# 2021-04-06  0.002462 -0.005620  0.133441  0.041582  0.001343 -0.004858
# 2021-04-07  0.013390 -0.004932  0.031478 -0.002315  0.022687  0.008230
# 2021-04-08  0.019234 -0.003924 -0.034483  0.049090  0.011693  0.013405
#
#                  NKE        TM         U
# Date
# 2021-04-01 -0.002709 -0.012175  0.007676
# 2021-04-05  0.019543  0.007914 -0.004749
# 2021-04-06  0.015098 -0.011134  0.016203
# 2021-04-07 -0.004520  0.006834 -0.042453
# 2021-04-08 -0.020946 -0.008533  0.010726

# %%
# Quantile Method
ret[stonk].quantile(0.05)
# Out:
# -0.019797935179690244

# %%
# Monte Carlo method
days = 365
dt = 1 / days
mu = ret.mean()[stonk]
sigma = ret.std()[stonk]

# %%
def stock_monte_carlo(start_price, days, mu, sigma):
    price = np.zeros(days)
    price[0] = start_price
    
    shock = np.zeros(days)
    drift = np.zeros(days)
    
    for x in range(1, days): 
        shock[x] = np.random.normal(loc=mu*dt, scale=sigma*np.sqrt(dt))
        drift[x] = mu*dt
        price[x] = price[x-1] + (price[x-1] * (drift[x] + shock[x]))
    
    return price

# %%
sdf.head()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume  \
# Date
# 2020-07-16  97.500000  98.230003  97.040001  97.260002  96.459023  3594700
# 2020-07-17  96.949997  97.230003  96.040001  96.279999  95.487091  7405700
# 2020-07-20  95.500000  96.349998  95.110001  95.650002  94.862282  5822300
# 2020-07-21  96.919998  99.000000  96.099998  98.360001  97.549965  5855600
# 2020-07-22  98.160004  98.989998  97.910004  98.910004  98.095444  4097000
#
#             MA for 10 days  MA for 20 days  MA for 50 days  Daily Return
# Date
# 2020-07-16             NaN             NaN             NaN           NaN
# 2020-07-17             NaN             NaN             NaN     -0.010076
# 2020-07-20             NaN             NaN             NaN     -0.006543
# 2020-07-21             NaN             NaN             NaN      0.028332
# 2020-07-22             NaN             NaN             NaN      0.005592

# %%
start_price = 97

for run in range(100):
    plt.plot(stock_monte_carlo(start_price, days, mu, sigma))

plt.xlabel('Days')
plt.ylabel('Price')
plt.title('Monte Carlo Analysis')
plt.show()

# %%
runs = 10000
simulations = np.zeros(runs)

for run in range(runs):
    simulations[run] = stock_monte_carlo(start_price, days, mu, sigma)[days - 1]

# %%
q = np.percentile(simulations, 1)

plt.hist(simulations, bins=200)

# Starting price
plt.figtext(0.6, 0.8, s="Start Price: $%.2f"%start_price)

# Mean ending price
plt.figtext(0.6, 0.7, "Mean final price: $%.2f"%simulations.mean())

# Variance of the price 99% confidence
plt.figtext(0.6, 0.6, "VaR(0.99): $%.2f"%q)

# Plot a line at the 1% quantitle result
plt.axvline(x=q, linewidth=4, color='r')

# Title
plt.title(u"Final price distribution for NKE stonks after $% days"%days, weight='bold')
# Out:
# Text(0.5, 1.0, 'Final price distribution for NKE stonks after $ 365ays')
