# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yahooFinance

# %%
sns.set_style('whitegrid') # background
get_ipython().magic(u'matplotlib inline')

# %%
# Reading stock data from the internet using pandas
import pandas_datareader.data as web

# %%
# Time stamps
from datetime import datetime

# %%
# Float numbers
from __future__ import division

# %% [markdown]
# ## Fetch Data

# %%
# Stonks
stonks = ['AAPL', 'MSFT', 'DELL', 'CRWD', 'TM', 'NKE']

# %%
# start and end date for data grab
end = datetime.now()
start = datetime(end.year - 1, end.month, end.day)

# %%
stonk_data = {}

for stonk in stonks:
    stonk_data[stonk] = yahooFinance.download(stonk, start=start, end=end)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## Single Stonk Analysis

# %%
stonk = stonks[0]
print(stonk)
sdf = stonk_data[stonk]
sdf.head()
# Out:
# AAPL
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-07-15  98.989998  99.247498  96.489998  97.724998  97.070930  153198000
# 2020-07-16  96.562500  97.404999  95.904999  96.522499  95.876472  110577600
# 2020-07-17  96.987503  97.147499  95.839996  96.327499  95.682777   92186800
# 2020-07-20  96.417503  98.500000  96.062500  98.357498  97.699188   90318000
# 2020-07-21  99.172501  99.250000  96.742500  97.000000  96.350784  103433200

# %% [markdown]
# ### Daily closing price

# %%
sdf['Adj Close'].plot(legend=True, figsize=(10,4))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Total daily volume

# %%
sdf['Volume'].plot(legend=True, figsize=(10,4))
plt.show()

# %%
# Calculate the moving average of the stock
ma_day = [10,20,50]

for ma in ma_day:
    column_name = "MA for %s days"%(str(ma))

    sdf[column_name] = sdf['Adj Close'].rolling(window=ma).mean()

# %% [markdown]
# ### Moving average of closing price

# %%
sdf[['Close','MA for 10 days','MA for 20 days','MA for 50 days']].plot(subplots=False,figsize=(10,4))
plt.show()

# %% [markdown]
# ### Daily returns

# %%
# Analyse daily returns of stonk
sdf['Daily Return'] = sdf['Adj Close'].pct_change()
sdf['Daily Return'].plot(figsize=(10, 4), legend=True, linestyle='--', marker='o')
plt.show()

# %% [markdown]
# ### Avg daily return of the last year

# %%
sns.displot(sdf['Daily Return'].dropna(), bins=100, color='red')
plt.show()

# %%
sdf['Daily Return'].hist(bins=100)
plt.show()

# %% [markdown]
# ## Stonk List Analysis

# %%
df = yahooFinance.download(" ".join(stonks), start=start, end=end)
df.head()
# Out:
# [*********************100%***********************]  6 of 6 completed
#             Adj Close                                                \
#                  AAPL        CRWD       DELL        MSFT        NKE
# Date
# 2020-07-15  97.070930  103.150002  52.680000  206.044937  97.728477
# 2020-07-16  95.876472  101.059998  59.099998  201.964462  96.459023
# 2020-07-17  95.682777  101.430000  60.369999  200.934448  95.487091
# 2020-07-20  97.699188  106.720001  61.450001  209.570831  94.862282
# 2020-07-21  96.350784  106.599998  61.060001  206.748154  97.549965
#
#                             Close                                     ...  \
#                     TM       AAPL        CRWD       DELL        MSFT  ...
# Date                                                                  ...
# 2020-07-15  127.330002  97.724998  103.150002  52.680000  208.039993  ...
# 2020-07-16  126.489998  96.522499  101.059998  59.099998  203.919998  ...
# 2020-07-17  127.059998  96.327499  101.430000  60.369999  202.880005  ...
# 2020-07-20  127.279999  98.357498  106.720001  61.450001  211.600006  ...
# 2020-07-21  126.269997  97.000000  106.599998  61.060001  208.750000  ...
#
#                  Open                                        Volume           \
#                  DELL        MSFT        NKE          TM       AAPL     CRWD
# Date
# 2020-07-15  52.689999  209.559998  98.410004  127.820000  153198000  4948500
# 2020-07-16  58.619999  205.399994  97.500000  127.260002  110577600  5095900
# 2020-07-17  58.759998  204.470001  96.949997  127.080002   92186800  5725500
# 2020-07-20  60.299999  205.000000  95.500000  127.180000   90318000  5959200
# 2020-07-21  61.700001  213.660004  96.919998  127.230003  103433200  3626300
#
#
#                 DELL      MSFT      NKE      TM
# Date
# 2020-07-15   1949400  32179400  5343700  201500
# 2020-07-16  25350200  29940700  3594700  212400
# 2020-07-17   5674100  31635300  7405700  137000
# 2020-07-20   3104100  36884800  5822300  145600
# 2020-07-21   2762300  37990400  5855600  153000
#
# [5 rows x 36 columns]

# %%
closing_df = df['Adj Close']
closing_df.head()
# Out:
#                  AAPL        CRWD       DELL        MSFT        NKE  \
# Date
# 2020-07-15  97.070930  103.150002  52.680000  206.044937  97.728477
# 2020-07-16  95.876472  101.059998  59.099998  201.964462  96.459023
# 2020-07-17  95.682777  101.430000  60.369999  200.934448  95.487091
# 2020-07-20  97.699188  106.720001  61.450001  209.570831  94.862282
# 2020-07-21  96.350784  106.599998  61.060001  206.748154  97.549965
#
#                     TM
# Date
# 2020-07-15  127.330002
# 2020-07-16  126.489998
# 2020-07-17  127.059998
# 2020-07-20  127.279999
# 2020-07-21  126.269997

# %% [markdown]
# ## Daily return

# %%
daily_returns = closing_df.pct_change()
daily_returns.head()
# Out:
#                 AAPL      CRWD      DELL      MSFT       NKE        TM
# Date
# 2020-07-15       NaN       NaN       NaN       NaN       NaN       NaN
# 2020-07-16 -0.012305 -0.020262  0.121868 -0.019804 -0.012990 -0.006597
# 2020-07-17 -0.002020  0.003661  0.021489 -0.005100 -0.010076  0.004506
# 2020-07-20  0.021074  0.052154  0.017890  0.042981 -0.006543  0.001731
# 2020-07-21 -0.013802 -0.001124 -0.006347 -0.013469  0.028332 -0.007935

# %% [markdown]
# ## Compare daily return of 2 stonks

# %%
stonk1 = stonks[0]
stonk2 = stonks[1]
sns.jointplot(stonk1, stonk2, daily_returns, kind='scatter', color='purple')
# Out:
# /Users/aperkslabbe/opt/anaconda3/envs/stonk_analysis/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Compare daily return of multiple stonks

# %%
from IPython.display import SVG
SVG(url='http://upload.wikimedia.org/wikipedia/commons/d/d4/Correlation_examples2.svg')
